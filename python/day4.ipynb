# %% [markdown]
# ## **`PANDAS`**

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2026.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import pandas as pd

# %%
print(pd.__version__)
# Out:
# 2.2.2

# %% [markdown]
# # series :-A Series is like a single column in Excel or a list with labels (indexes).

# %%
s=pd.Series([1,2,3,4,5])

# %%
print(s)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
ser=pd.Series([1,2,3,4,5],index=['a','b','c','d','e'])
print(ser)
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
student={
    "name":"vamsi",
    "branch":"aiml"
    }
ser=pd.Series(student)
print(ser)
# Out:
# name      vamsi
# branch     aiml
# dtype: object

# %%
n=pd.Series([10,20,30,40,50])

# %%
n+2
# Out:
# 0    12
# 1    22
# 2    32
# 3    42
# 4    52
# dtype: int64

# %%
n/2
# Out:
# 0     5.0
# 1    10.0
# 2    15.0
# 3    20.0
# 4    25.0
# dtype: float64

# %%
s.mean()
# Out:
# np.float64(3.0)

# %%
s.max()
# Out:
# 5

# %%
s.sum()
# Out:
# np.int64(15)

# %%
s.describe()
# Out:
# count    5.000000
# mean     3.000000
# std      1.581139
# min      1.000000
# 25%      2.000000
# 50%      3.000000
# 75%      4.000000
# max      5.000000
# dtype: float64

# %%
n[n>20]
# Out:
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
names=pd.Series(['bunny','Rohith','YUNUS'])

# %%
names.str.lower()
# Out:
# 0     bunny
# 1    rohith
# 2     yunus
# dtype: object

# %%
names.str.len()
# Out:
# 0    5
# 1    6
# 2    5
# dtype: int64

# %%
names.str.startswith('Y')
# Out:
# 0    False
# 1    False
# 2     True
# dtype: bool

# %%
student={
    "names":["bunny","rohith","gani"],
    "branch":["aiml","aiml","aiml"]
}
std=[
    {"name":"bunny","branch":"aiml","age":20,},
    {"name":"rohith","branch":"aiml"},
    {"name":"gani","branch":"aiml"}
]
s=pd.DataFrame(std)
print(s)
# Out:
#      name branch   age
# 0   bunny   aiml  20.0
# 1  rohith   aiml   NaN
# 2    gani   aiml   NaN

# %%
import numpy as np

# %%
arr= np.random.rand(3,4)
c=pd.DataFrame(arr,columns=['a','b','c','d'])
print(c)
# Out:
#           a         b         c         d
# 0  0.736824  0.500892  0.481459  0.385028
# 1  0.948852  0.321876  0.192430  0.387504
# 2  0.091132  0.410583  0.938805  0.400915

# %%
data={
    "names":["bunny","bunny","gani"],
    "age":[20,21,22],
    "score": [90,91,92],
    "branch":["aiml","aiml","aiml"]
}
df=pd.DataFrame(data)
print(df)
# Out:
#    names  age  score branch
# 0  bunny   20     90   aiml
# 1  bunny   21     91   aiml
# 2   gani   22     92   aiml

# %%
df.tail()
# Out:
#    names  age  score branch
# 0  bunny   20     90   aiml
# 1  bunny   21     91   aiml
# 2   gani   22     92   aiml

# %%
df.head()
# Out:
#    names  age  score branch
# 0  bunny   20     90   aiml
# 1  bunny   21     91   aiml
# 2   gani   22     92   aiml

# %%
df.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_535/1472378890.py in <cell line: 0>()
# ----> 1 df.shape()
#
# TypeError: 'tuple' object is not callable

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
df.dtypes
# Out:
# names     object
# age        int64
# score      int64
# branch    object
# dtype: object

# %%
df.nunique()
# Out:
# names     2
# age       3
# score     3
# branch    1
# dtype: int64

# %%
df.isnull().sum()
# Out:
# names     0
# age       0
# score     0
# branch    0
# dtype: int64

# %%
df['names']
df.names
# Out:
# 0    bunny
# 1    bunny
# 2     gani
# Name: names, dtype: object

# %%
df[['names','age']]
# Out:
#    names  age
# 0  bunny   20
# 1  bunny   21
# 2   gani   22

# %%
df.loc[0]
# Out:
# names     bunny
# age          20
# score        90
# branch     aiml
# Name: 0, dtype: object

# %%
df.loc[0:3,"names":"score"]
# Out:
#    names  age  score
# 0  bunny   20     90
# 1  bunny   21     91
# 2   gani   22     92

# %%
df.iloc[-1]
# Out:
# names     gani
# age         22
# score       92
# branch    aiml
# Name: 2, dtype: object

# %%
df.loc[0,'names']
# Out:
# 'bunny'

# %%
df.iloc[0,0]
# Out:
# 'bunny'
